# %% [markdown]
# ![ntust-2.jpg](attachment:ntust-2.jpg)
#
# # Group 1 - Contact Information Program
# 故事背景：台科大管理學院辦公室目前沒有資料庫的系統，各個職位間的聯絡資訊仍是使用紙本紀錄。<br>
# 管理學院院長認為此沒有效率，因此希望前往暑期打工的你可以協助建立一個資料庫系統，讓聯絡資訊能夠電子化。<br>
# The office of the School of Management of NTUST currently does not have a database system, and the contact information between various staff is still using paper records. Dean of the School of Management thinks this is inefficient. Therefore, he asked you as a summer job worker to build a database system so that contact information can be digitized.

# %% [markdown]
# ![address-book.png](attachment:address-book.png)
#
# ## 第一題：建立通訊錄
# 辦公室內原有7名教職員，請將其資訊建立通訊錄。<br>
# ## Question 1:
# Create an employee directory with query functions <br> There are 7 faculty members in the office,
# please create an employee directory with their information.
#
# | No | Name | Number |
# | --- | --- | --- |
# | 1 | Anita | 0917583928 |
# | 2 | Bob | 0965756213 |
# | 3 | Carl | 0976578329 |
# | 4 | Deddy | 0945786663 |
# | 5 | Edward | 0936438192 |
# | 6 | Frank | 0938562795 |
# | 7 | Gill | 0952718726 |
#
# ### Expected Output
# #### Contact Book
#
# | No | Name |
# | --- | --- |
# | 1 | Anita |
# | 2 | Bob |
# | 3 | Carl |
# | 4 | Deddy |
# | 5 | Edward |
# | 6 | Frank |
# | 7 | Gill |

# %%
#Initialization for contact book

contact
# Out:
# {'Anita': '0917583928',
#  'Bob': '0965756213',
#  'Carl': '0976578329',
#  'Debby': '0945786663',
#  'Edward': '0936438192',
#  'Frank': '0938562795',
#  'Gill': '0952718726'}

# %%
#Create a list with the contact with names only
# Out:
# Contact Book
# 1. Anita
# 2. Bob
# 3. Carl
# 4. Debby
# 5. Edward
# 6. Frank
# 7. Gill

# %% [markdown]
# ![look-for.png](attachment:look-for.png)
#
# # 第二題：查詢功能
# 請試著讓使用者能透過通訊錄的編號或是姓名查詢電話。<br>
# # Question 2: Selecting Contacts
# For the user to easily access the contact book, you are tasked to create a simple selection program where the contact could be chosen **Either** with **Name** or **List Number**
# #### Contact Book
#
# | No | Name |
# | --- | --- |
# | 1 | Anita |
# | 2 | Bob |
# | 3 | Carl |
# | 4 | Deddy |
# | 5 | Edward |
# | 6 | Frank |
# | 7 | Gill |
#
# <br>
#
# #### < Input >
# Please select a contact: Anita **OR** Please select a contact: 1
#
# #### < Expected Output >
# Anita - 0917583928

# %%
#Make listing function
def listing(a):

# %%
# Out:
# Contact Book
# 1. Anita
# 2. Bob
# 3. Carl
# 4. Debby
# 5. Edward
# 6. Frank
# 7. Gill
# Please select a contact: Anita
# Anita - 0917583928

# %%
#Make the program into functions
#To check input
def int_string(i):


#To get name and number when input is integer
def endResultInt(a,contact):


#To get name and number when input is string
def endResultStr(a,contact):


#Selection Program
def selection():

# %% [markdown]
# ![1201teachers.jpg](attachment:1201teachers.jpg)
#
# # 第三題：新增及修改通訊錄
# 一個月後，新增了2名助教，另外一名秘書需要更改通訊錄電話，請增加設計使系統可以新增及更改資訊。
# # Question 3: Adding and Editing Contacts
# One month later, 2 teaching assistants were added, and one secretary needed to change the phone number of the employee directory. Please add a function so that the system can add and edit information.
#
# < Please make sure the input can only be **NUMBER**, not string. <br>
# Hint: Use the function above to check if the input is **NUMBER** >
#
# | Function | Name | Number |
# | --- | --- | --- |
# | Add | Hannah | 0927583928 |
# | Add | Ivan | 0938756273 |
# | Edit | Frank | 0989513799 |

# %%
#use while loop
# Out:
# Contact Book
# 1. Anita
# 2. Bob
# 3. Carl
# 4. Debby
# 5. Edward
# 6. Frank
# 7. Gill
# 8. Hannah
# 9. Ivan
# Type a function: edit
# Which contact you want to edit? Frank
# Edit contact number: 0989513799
# Old number: Frank - 0938562795
# New number: Frank - 0989513799
# Are you sure the name and number is correct? (Y/N): y
# Contact Book
# 1. Anita
# 2. Bob
# 3. Carl
# 4. Debby
# 5. Edward
# 6. Frank
# 7. Gill
# 8. Hannah
# 9. Ivan

# %%
#Recheck the updated contact book
# Out:
# Contact Book
# 1. Anita
# 2. Bob
# 3. Carl
# 4. Debby
# 5. Edward
# 6. Frank
# 7. Gill
# 8. Hannah
# 9. Ivan
# Please select a contact: Frank
# Frank - 0989513799

# %% [markdown]
# ![delete-4.jpg](attachment:delete-4.jpg)
#
# # 第四題：刪除
# 再過了一個月，兩名助教要離職，請替系統新增刪除功能
# # Question 4: Delete function
# In another month, two teaching assistants are leaving, please add a delete function to the system.
#
# | Function | Name |
# | --- | --- |
# | Delete | Debby |
# | Delete | Ivan |

# %%
# Out:
# Contact Book
# 1. Anita
# 2. Bob
# 3. Carl
# 4. Edward
# 5. Frank
# 6. Gill
# 7. Hannah
# 8. Ivan
# Type a function: Delete
# Enter contact name or list number: 8
# Ivan - 0938756273
# Do you want to delete this contact? (Y/N)y
# Contact Book
# 1. Anita
# 2. Bob
# 3. Carl
# 4. Edward
# 5. Frank
# 6. Gill
# 7. Hannah

# %% [markdown]
# ![part-time%20student.jpg](attachment:part-time%20student.jpg)
#
# # 第五題：整合
# 暑假結束了，你也要離職了。院長希望您能夠將系統完整寫完，使其他人能夠更順利地使用。因此，麻煩您將前述所有功能融合在一起，形成一個可以直接使用查詢、新增、修改、刪除的電子通訊錄。
# # Question 5: System Integration
# Summer vacation is over, and you are leaving. The Dean wants you to integrate the system so others can use it more clearly. Therefore, please integrate all the above functions together to form an electronic employee directory that can be directly used to query, add, edit, and delete. <br>
# < Hint: Use function to make the codes easier to read and use **while** loop to form an electronic employee directory >

# %%
#Define functions
#Functions
def listing(a):


def int_string(i):

    
def endResultInt(a,contact):


def endResultStr(a,contact):

# %%
# Out:
# 'Edward'

# %%
#Main Functions
# Out:
# Contact Book
# Type Add, Delete or Exit
# Contact Book
# 1. Anita
# 2. Bob
# 3. Carl
# 4. Edward
# 5. Frank
# 6. Gill
# 7. Hannah
# Please select a contact: edit
# Which contact you want to edit? 5
# Edit contact number: 0989513799
# Old number: Frank - 0989513799
# New number: Frank - 0989513799
# Are you sure the name and number is correct? (Y/N): y
# Contact Book
# 1. Anita
# 2. Bob
# 3. Carl
# 4. Edward
# 5. Frank
# 6. Gill
# 7. Hannah
# Please select a contact: 5
# Frank - 0989513799
# Please select a contact: exit
# Thank you for using this application
